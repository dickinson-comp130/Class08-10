# %% [markdown]
# # Class 08-10 - User Defined Functions
# **COMP130 - Introduction to Computing**
# **Dickinson College**

# %% [markdown]
# ### Names:

# %% [markdown]
# ### Function Definitions

# %% [markdown]
# __Q1:__ Enter the functions `print_horiz_bar`, `print_center_vert_bar` and `print_T` from the __UserDefFuncsExamples.ipynb__ notebook into the code cell below.  Add at the bottom of the cell a call to the `print_T` function.  Run the cell to ensure that everything has been entered without any syntax errors.

# %% [markdown]
# __Q2:__ List is the *header*s of the function defined in __Q1__?

# %% [markdown]
# __Q3:__ What happens if you forget the `:` at the end of a method header?

# %% [markdown]
# __Q4:__ The indentation of the *body* of a function is important in Python. It is what indicates to the Python interpreter which statements are in the body of the function. What happens if you indent any the first three  `print` statements in the `print_center_vert_bar` function more or less than the others and re-run the cell?

# %% [markdown]
# __Q5:__ What happens if you un-indent the last `print` statement in the `print_center_vert_bar`? Why do you think that happens?

# %% [markdown]
# __Q6:__ It should be clear that the statements in an function body must all be indented at the same level. Does it matter what that level is (i.e. how many spaces are used)?  How did you figure this out?

# %% [markdown]
# __Q7:__ Move the *call to* the `print_T` function above *the definition of* the `print_T` function? What general rule could you state about the order in which a function definition and a function call must appear?

# %% [markdown]
# __Q7:__ Does the rule that you stated in __Q7__ apply to function calls that appear within other functions (e.g. the `print_T` function contains a call to the `print_horz_bar()` function)? How did you figure this out?

# %% [markdown]
# ### Calling Functions

# %% [markdown]
# __Q8:__ What output would be generated by the following function calls?
# ```Python
# print_horiz_bar()
# print_T()
# ```
#
# Note: To get the markdown cell to display your output the way that you format it you will need to enclose it between triple back ticks. For example:
# ````
# ```
# This
#   will display
#  exactly
#    as
#      formatted.
# ```
# ````

# %% [markdown]
# __Q9:__ Rearrange the following `print` statements and function calls into the code cell below so that they display the letter "E".
# ```
# print('*')
# print('*')
# print('*')
# print_horiz_bar()
# print_horiz_bar()
# print('*')
# ```

# %% [markdown]
# __Q10:__ Write a program using only calls to functions defined in __Q1__ that display an extra tall letter "`I`" with extra thick top and bottom lines.

# %% [markdown]
# ### Writing Functions

# %% [markdown]
# __Q11:__ Define a function named `print_E` based on your answer to __Q9__.

# %% [markdown]
# __Q12:__ Call your `print_E` function to ensure that it works.

# %% [markdown]
# __Q13:__ In the code cell below, write a function named `print_side_bars` that prints a "\*" three spaces and another "\*".

# %% [markdown]
# __Q14:__ In the code cell below, write a function named `print_A` that prints the letter "A" using only calls to other functions that have been defined. Note: Your "A" will be very square looking.

# %% [markdown]
# __Q15:__ Call to your `print_A` function in the code cell below to check that it works.

# %% [markdown]
# __Q16:__ Write a function called `print_EAT` that prints the word "EAT" with a blank line between each of the letters.

# %% [markdown]
# __Optional:__ Define some additional basic functions, like `print_horiz_bar` or `print_side_bars`, that will allow you to create one or more other letters.  Then write functions that print those letters.  Then write a function that prints a word.

# %% [markdown]
# ![Stop sign](stop.png)
# End of Class 08 material.

# %% [markdown]
# ### Functions, Parameters and Arguments

# %% [markdown]
# __Q16:__ Consider the program below.  What is the name of the *parameter* in the function that is defined?  What is the value of the *argument* that is assigned to that parameter?

# %%
def print_horiz_bar(width):
    print('*'*width)
    
print_horiz_bar(9)

# %% [markdown]
# __Q17:__ Parameter names and function names, like variable names, are chosen for human readers. The Python interpreter does not care what variables or parameters are named as long as they are used consistently.  Rewrite the program above naming the function `phb` and the parameter `w`.

# %% [markdown]
# __Q18:__ As a human reader (e.g. another programmer, your TA, your instructor), which program would be easier to understand, the one in __Q16__ or __Q17__?

# %% [markdown]
# ### Call Stacks

# %% [markdown]
# Consider the program below.  This program has been written so that it is confusing to read. Its purpose is not to do any useful computation, but rather to give you practice tracing the execution of a program and creating a *stack diagram*.  Don't run this program yet.  Complete the questions below first.

# %%
def fun3(a,b):
  a = 2*b+a  # Line D
  print("fun3: a=" + str(a) + " b=" + str(b))

def fun2(b, a):
  b = a+b
  a = b-a # Line C
  fun3(b,a)
    
def fun1(a):
  a = a+1 # Line B
  fun2(3*a, a)
    
a=3  # Line A
fun1(a)

# %% [markdown]
# __Q19:__ Draw a *stack diagram* for the program just after the line labeled __Line A__ has executed.  This diagram should include only the `__main__` *frame*.  Put a picture of your stack diagram in the markdown cell below.

# %% [markdown]
# __Q20:__ Add a *frame* to your *stack diagram* that shows the state of the program's execution just after __Line B__ has executed. Put a picture of your updated stack diagram in the markdown cell below.

# %% [markdown]
# __Q21:__ Add frames to your stack diagram to show the state of the program's execution just after __Line D__ has executed.  Put a picture of your updated stack diagram in the markdown cell below.

# %% [markdown]
# __Q22:__ Now run the code cell above.  It will print out the values of `a` and `b` just after __Line D__ has executed.  Compare these to those that appear in the stack frame for `fun3` in your answer to __Q21__.  If they do not match, re-visit your answers to __Q19__-__Q21__ to figure out where you went wrong, and update your state diagrams in those answers.

# %% [markdown]
# ### Errors and Tracebacks

# %% [markdown]
# You have seen that the Python interpreter will give you an error message when your program encounters a runtime error.  When an error occurs in a function that has been called (possibly from another function and so on), the error message will contain *traceback* information.
#
# For example, if `Line D` in the program above is changed to read: `a = 2*b/(b-12)` and then run, the error message shown below is generated.
#
# ```Python
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-37-1e16878fe063> in <module>
#      13
#      14 a=3  # Line A
# ---> 15 fun1(a)
#      16
#
# <ipython-input-37-1e16878fe063> in fun1(a)
#      10 def fun1(a):
#      11   a = a+1 # Line B
# ---> 12   fun2(3*a, a)
#      13
#      14 a=3  # Line A
#
# <ipython-input-37-1e16878fe063> in fun2(b, a)
#       6   b = a+b
#       7   a = b-a # Line C
# ----> 8   fun3(b,a)
#       9
#      10 def fun1(a):
#
# <ipython-input-37-1e16878fe063> in fun3(a, b)
#       1 def fun3(a,b):
# ----> 2   a = 2*b/(b-12) # Line D
#       3   print("fun3: a=" + str(a) + " b=" + str(b))
#       4
#       5 def fun2(b, a):
#
# ZeroDivisionError: division by zero
# ```

# %% [markdown]
# __Q23:__ What is the name of the specific Python error that occurred? What type of error is that (runtime, semantic, syntax?)  What caused the error to occur?

# %% [markdown]
# __Q24:__ How is the line that generated the error indicated?  Is this line at the top or bottom end of the traceback information? What is at the other end of the traceback?

# %% [markdown]
# __Q25:__ Use a bulleted list in the markdown cell below to answer the following questions based on the information in the traceback:
# - On what line number did the error occur?
# - In which function did the error occur?
# - On what line did `fun2` call `fun3`?
# - On what line did `fun1` call `fun2`?
# - On what line was `fun1` called?

# %% [markdown]
# __Q26:__ How is the traceback information related to the *call stack*?

# %% [markdown]
# ### Writing Functions with Parameters

# %% [markdown]
# __Q27:__ Rewrite your `print_side_bars` function from __Q13__ so that it accepts a `width` parameter and inserts an appropriate number of spaces between the side bars.

# %% [markdown]
# __Q28:__ Rewrite your `print_A` function from __Q14__ so that it can print an "A" with its width specified by an argument.  Be sure to run the code cell in __Q16__ so that the `print_horiz_bar` function is defined and can be used.

# %% [markdown]
# __Q29:__ Write a program that prompts the user for the width of the letters and then prints the word "AT" in the specified side.  You will need to copy a few functions from the __UserDefFuncsExamples.ipynb__ notebook into this one to complete this exercise.

# %% [markdown]
# __Q30:__ All word processors allow you to center text on the page.  This is useful for things like titles, section headings and figure captions.  Write a function named `print_centered_text` takes a string and a page width specified as a number of characters as arguments.  The function then prints out the string centered in the specified width.  For example the program:
# ```Python
# print_centered_text("This text is",20)
# print_centered_text("centered",20)
# print_centered_text("in twenty spaces",20)
# ```
#
# will generate the output:
# ```
#     This text is
#       centered
#   in twenty spaces
# ```
#
# Note: To solve this problem you will need to find the length of the string provided.  Python provides a built-in function named `len` that returns the length of a string passed to it as an argument.  For example the statement: `str_length=len("This text is")` will assign the `int` value `12` into the variable `str_length`.

# %% [markdown]
# ![Stop sign](stop.png)
# End of Class 09 material.

# %% [markdown]
# __Q31:__ Write a function using your `print_centered_text` function from __Q30__ that displays a more normal looking A.  The A can be a fixed size, but should be able to be printed in any character, not just "*".  For for example your "A" might appear like:
# ```
#     X
#    X X
#   XXXXX
#  X     X
# X       X
# ```
# Include calls to your function that displays your new "A" using at least two different characters.

# %% [markdown]
# __Q32:__ Write a program that prints a rectangle with a specified width and height. For example, a 5x3 rectangle might appear like:
# ```
# +---+
# |   |
# +---+
# ```
# Divide the work of your program into appropriate functions to avoid repeating your `print` statements.
#
# Include program statements that use function calls to print at least two rectangles of two different sizes.

# %% [markdown]
# __Q33:__ Consider the start of a program in the code cell below.  This code creates a `Turtle` object and passes it to the function `draw_square`.  The `draw_sqaure` function is not complete.  Add code to the program to complete this function.

# %%
import turtle

def draw_square(t):
    t.forward(50)
    t.left(90)
    # More to be added here.
    
amy=turtle.Turtle()
draw_square(amy)

# %% [markdown]
# __Q34:__ Revise your solution to __Q33__ so that the `draw_square` function can draw squares of different sizes.

# %% [markdown]
# __Q35:__ Write a program that uses the `draw_square` function from __Q33__ to draw a 2x2 grid.  Hint: Move the turtle to a new starting point between calls to `draw_square`.

# %% [markdown]
# __Q36:__ Write a function that accepts a `Turtle` object, a length and an x,y location as arguments and draws a [Star of David](https://en.wikipedia.org/wiki/Star_of_David) centered at x,y with lines of the specified length. Note that the star is created from two equilateral triangles.  The interior angle of each angle in an equilateral triangle is 180/3 = 60 degrees. Use functions to subdivide the problem into smaller problems. Include program statements that draw at least two stars of two different sizes at two different locations.
